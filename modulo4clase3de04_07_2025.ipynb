# %% [markdown]
# <a href="https://colab.research.google.com/github/LirBast/Bootcamp2/blob/main/modulo4clase3de04_07_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(777)

horas_estudio=np.random.uniform(1,10,20)

print(horas_estudio[0:5])

nota_examen=horas_estudio*0.8+np.random.normal(0,1,20)
print('----------------------------')
print(nota_examen[0:5])   ## [0:5] como es una lista, esto hace que se impriman solo los primeros 5 numeros

# %%
import numpy as np
import pandas as pd


# np.random.seed(777)   ### si quiero tener siempre los mismo numeros le aplico la seed

genero=np.random.choice(['Hombre','Mujer'],size=50)

preferencias=[]

for g in genero:
    if g == 'Mujer':
        preferencias.append(np.random.choice(['si','no'],p=[0.6,0.4]))
    else:  # Hombre
        preferencias.append(np.random.choice(['si','no'],p=[0.4,0.6]))

datos = pd.DataFrame({'Genero': genero,
                      'Preferencia': preferencias})

print(datos.head())



## tabla de contingencia

tabla_contingencia=pd.crosstab(datos['Genero'],datos['Preferencia'])

print('----------------------------')
print(tabla_contingencia)
print('----------------------------')
cantidad_mujeres=tabla_contingencia.loc['Mujer'].sum() ### el loc sirve para acceder a fila o columnas del data frame
## Cantidad de mujeres
print(cantidad_mujeres)
print('----------------------------')
# mujeres que si quieren ir al cine
mujeres_pref_cine=tabla_contingencia.loc['Mujer','si'].sum()
print(mujeres_pref_cine)
print('----------------------------')
probabilidad_mujer_si=mujeres_pref_cine/cantidad_mujeres
##probabilidad de mujeres que si quieren ir al cine
print(probabilidad_mujer_si)
print('----------------------------')
### Hombres que no quieren ir al cine
hombres_pref_cine=tabla_contingencia.loc['Hombre','no'].sum()
print(hombres_pref_cine)

# %%
### Grafico de Diagrama de dispersion
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import pearsonr

horas_estudio=np.random.uniform(1,10,20)
nota_examen =horas_estudio*0.8 + np.random.normal(0,1,20)

df = pd.DataFrame({'horas_estudio':horas_estudio,
                   'Notas_examen':nota_examen})
print(df.head()) ### solo muestra los primeros 5 valores

plt.figure(figsize=(8,6))
plt.scatter(df['horas_estudio'],df['Notas_examen'])
plt.xlabel('Horas de estudio')
plt.ylabel('Nota en examen')
plt.title('Diagrama de dispersión: Horas de estudio vs Nota examen')
plt.grid(True)
plt.show()

### Calculo de coeficiente de pearson

coef, p_valor = pearsonr(df['horas_estudio'], df['Notas_examen'])
print(coef)
print(p_valor)

if coef >=0.7 or coef<=-0.7:
  if p_valor<0.05:
    print('Es una correlacion fuerte y problamente real')
  else:
    print('Es una correlacion fuerte pero problamente del azar')
# Out:
#    horas_estudio  Notas_examen
# 0       4.828878      5.001278
# 1       9.364919      7.863825
# 2       3.932183      4.529098
# 3       9.598947      8.392869
# 4       7.074988      4.277430
# 0.9251714184850989
# 5.31247264006098e-09
# Es una correlacion fuerte y problamente real

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c5f380a2-c7bc-44a3-865d-6c5be1f0512a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5f380a2-c7bc-44a3-865d-6c5be1f0512a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('ai_job_dataset.csv')
print(df)
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...
